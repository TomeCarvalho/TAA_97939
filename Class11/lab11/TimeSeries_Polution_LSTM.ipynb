# %% [markdown]
# # Lab  - LSTM for Air Polution Forecasting
#
#
#
# **Objectives**: Apply Long Short-Term Memory (LSTM) Recurrent Neural Network (RNN) for
# Multivariate Time Series Forecasting.
#
# **The forecasting problem**: Air Quality dataset reports on the weather and the level of pollution each hour over 5 years at the US embassy in Beijing, China. Given the weather conditions and pollution for prior hours, forecast the pollution at the next hour.
#
# Data includes the date-time, the pollution called PM2.5 concentration, and the weather information including dew point, temperature, pressure, wind direction, wind speed and the cumulative number of hours of snow and rain. The complete list of data is as follows:
#
# **Total data**: 43800 samples (5 years x 365 days x 24 hours), 8 features.
#
# **year-month-day-hour**: date of data in this row
#
# **pm2.5**: PM2.5 concentration  (**pollution indicator => the predicted variable**)
#
# **DEWP**: Dew Point (DewP indicates the amount moisture in the air. The higher the dewP, the higher the moisture content of the air at a given temperature.
#
# **TEM**P: Temperature
#
# **PRES**: Pressure
#
# **cbwd**: Combined wind direction (categorical feature, 4 values, e.g. Sought-East (SE))
#
# **Iws**: Cumulated wind speed
#
# **Is**: Cumulated hours of snow
#
# **Ir**: Cumulated hours of rain

# %%
import warnings
warnings.filterwarnings('ignore',category=FutureWarning)
warnings.filterwarnings('ignore',category=RuntimeWarning)

import numpy as np
from numpy import concatenate
from matplotlib import pyplot
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

# %% [markdown]
# ## Load Data
# Use function *read_csv* to load data from file *pollution.csv*.
# This function will create dataframe dataset.
#
# Dataframe consists not only of values but also
# the names of the columns, the indices of the rows.

# %%
dataset = read_csv("pollution.csv")

#Print the dimension of dataset 
print(f"{dataset.shape = }")

#Print the first few lines of the structure dataset 
dataset.head()

#Print only the names of the columns
print(f"{dataset.columns = }")

n_features = dataset.shape[1] #number of features 

# Extract only the values of dataframe and ignore the column with the date. 
values = dataset[['pollution', 'dew', 'temp', 'press', 'wnd_dir', 'wnd_spd', 'snow', 'rain']].to_numpy()
# print(f"{values = }")
# Out:
# dataset.shape = (43800, 9)
# dataset.columns = Index(['date', 'pollution', 'dew', 'temp', 'press', 'wnd_dir', 'wnd_spd',
#        'snow', 'rain'],
#       dtype='object')

# %% [markdown]
# ## Plot Data
# Plot the data and get a figure similar to Fig.1
# <img src="images/f1.png" style="width:350px;height:250px;">
# <caption><center> **Fig. 1** : ** Pollution & Weather Time series dataset** </center></caption>

# %%
##use for example pyplot
import matplotlib.pyplot as plt

for i, feature in enumerate(['pollution', 'dew', 'temp', 'press', 'wnd_dir', 'wnd_spd', 'snow', 'rain']):
    plt.figure(i)
    plt.plot(values[:, i])
    plt.title(feature)

# %% [markdown]
# ## LSTM Data Preparation
# Prepare the dataset for the LSTM, that is, frame the dataset as a supervised learning problem to predict the pollution (pm2.5) at the current or future hours given the past pollution and weather conditions over a number of prior time steps (hours).
#
#
# **Original data frame (each row has data of only that hour)** :
#
# row 1=> var1(t), var2(t),...var8(t)
#
# row 2=> var1(t-1), var2(t-1),...var8(t)
#
# row 3=> .....
#
# **After series_to_supervised (each row has data of n previous hours and the current hour)**:
#
#
# row 1=> var1(t-n), var2(t-n),...var8(t-n), var1(t-n+1), var2(t-n+1),...var8(t-n+1), .....var1(t), var3(t),...var8(t)
#
# row 2=> var1(t-n-1), var2(t-n-1),...var8(t-n-1), var1(t-1), var3(t-1),...var8(t-1)
#
# row 3 => ...

# %%
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True): 
    """
        data: data matrix
        n_in: number of input lag timesteps (hours)
        n_out: number of output prediction timesteps (hours)
 
    """
        
    n_vars = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)  #transforms data (pure matrix of values) into data structure adding index of rows and columns
    cols, names = list(), list()  #inicialize empty lists 
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
# encode the categorical feature cbwd: Combined wind direction (4 categorical values) into integers (0,1,2,3)

encoder = LabelEncoder()
values[:,4] = encoder.fit_transform(values[:,4]) # transform the 5th column into integers 0,1,2,3

# ensure all data is float
values = values.astype('float32')

# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)  #apply scaler to the values 


# specify the number of lag hours. You can change this hyper-parameter
lag_hours = 3

# call series_to_supervised to frame data as supervised learning
reframed = series_to_supervised(scaled, n_in=lag_hours)

#Print the dimension of  the dataframe reframed: ANSWER=(43797, 32) 
print(f"{reframed.shape = }")

#Print the first few lines of reframed
reframed.head()

# we want to predict only the feature pm2.5 =var1(t)
# Take out the columns of var2(t), var3(t),...var8(t).

reframed.drop([f"var{i}(t)" for i in range(2, 9)], axis=1, inplace=True)

#Print the new dimension of  reframed: ANSWER=(43797, 25) 
print(f"New dimension: {reframed.shape = }")

#Print the first few lines of the new reframed
print("New reframed")
reframed.head()
# Out:
# reframed.shape = (43797, 32)
# New dimension: reframed.shape = (43797, 25)
# New reframed
#    var1(t-3)  var2(t-3)  var3(t-3)  var4(t-3)  var5(t-3)  var6(t-3)  \
# 3   0.129779   0.352941   0.245902   0.527273   0.666667   0.002290
# 4   0.148893   0.367647   0.245902   0.527273   0.666667   0.003811
# 5   0.159960   0.426471   0.229508   0.545454   0.666667   0.005332
# 6   0.182093   0.485294   0.229508   0.563637   0.666667   0.008391
# 7   0.138833   0.485294   0.229508   0.563637   0.666667   0.009912
#
#    var7(t-3)  var8(t-3)  var1(t-2)  var2(t-2)  ...  var8(t-2)  var1(t-1)  \
# 3   0.000000        0.0   0.148893   0.367647  ...        0.0   0.159960
# 4   0.000000        0.0   0.159960   0.426471  ...        0.0   0.182093
# 5   0.000000        0.0   0.182093   0.485294  ...        0.0   0.138833
# 6   0.037037        0.0   0.138833   0.485294  ...        0.0   0.109658
# 7   0.074074        0.0   0.109658   0.485294  ...        0.0   0.105634
#
#    var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  var7(t-1)  \
# 3   0.426471   0.229508   0.545454   0.666667   0.005332   0.000000
# 4   0.485294   0.229508   0.563637   0.666667   0.008391   0.037037
# 5   0.485294   0.229508   0.563637   0.666667   0.009912   0.074074
# 6   0.485294   0.213115   0.563637   0.666667   0.011433   0.111111
# 7   0.485294   0.213115   0.581818   0.666667   0.014492   0.148148
#
#    var8(t-1)   var1(t)
# 3        0.0  0.182093
# 4        0.0  0.138833
# 5        0.0  0.109658
# 6        0.0  0.105634
# 7        0.0  0.124748
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Split Data
#
# First, data is split into train and test subsets. To speed up the model fiting, the training data is only the
# 1st year, the test data are the remaining 4 years. You may consider exploring the oposite.
#
# Then the train and test sets are split into input and output variables.
#
# Finally, the inputs (X) are reshaped into 3D format expected by LSTMs, namely [samples, timesteps, features].
#
# **Total data**: 43800 samples (5 years x 365 days x 24 hours), 8 features.
#
# **Train data**: 3D tensor(samples, timesteps, features).
# 8760 samples:  Data from 1 year (365 days), 24 times per day (1h period).
#
# **Test data**: 3D tensor (samples, timesteps, features). The rest of 35037 samples.

# %%
# split into train and test sets

# reframed is a dataframe that has not only values but also heads and row indixes. 
#Extract only the values 

values = reframed.values
n_train_hours = 365 * 24  #8760 (1 year, 24 times per day, i.e. period 1h)

#Extract training subset from values 
train = values[:n_train_hours, :]

#Extract test subset from values 
test = values[n_train_hours:, :]

train_X = train[:, :-1]   # train_X.shape = (8760, 24)
train_y = train[:, -1]  # train_y.shape = (8760,)

test_X = test[:, :-1]      # test_X.shape = (35037, 24)
test_y = test[:, -1] # test_y.shape = (35037,)

print(f"""
{train_X.shape = }
{train_y.shape = }
{test_X.shape = }
{test_y.shape = }
""")

# reshape input to be 3D [samples, lag_hours, features]
train_X = train_X.reshape(train_X.shape[0], lag_hours, 8) # train_X.shape=(8760,3,8)
test_X = test_X.reshape(test_X.shape[0], lag_hours, 8)  # test_X.shape=(35037,3,8)

print(f"""
After reshaping
{train_X.shape = }
{test_X.shape = }
""")
# Out:
# train_X.shape = (8760, 24)
# train_y.shape = (8760,)
# test_X.shape = (35037, 24)
# test_y.shape = (35037,)
#
#
# After reshaping
# train_X.shape = (8760, 3, 8)
# test_X.shape = (35037, 3, 8)

# %% [markdown]
# ## Define and Fit Model
#
# In this section, we define and fit an LSTM on the multivariate input data.
# We define the LSTM with 50 neurons in the first hidden layer and 1 neuron in the output layer for predicting pollution.
# We use the Mean Absolute Error (MAE) loss function and the Adam version of stochastic gradient descent.
# The model will be fit for 50 training epochs with a batch size of 72.
# At the end of the run both the training and test loss are plotted.

# %%
# Sequential model is appropriate to design LSTM RNN
model = Sequential()
# train_X : 3D tensor (samples, lag_hours, feature)
# neurons =50
# single input_shape = (lag_hours, feature)
model.add(LSTM(50, input_shape=(lag_hours, 8)))
model.add(Dense(1))  # 1 neuron in the output layer
model.compile(loss='mae', optimizer='adam')

# fit network
#verbose=0 will show nothing (silent)
#verbose=1 will show an animated progress bar
#verbose=2 will show the training progress for each epoch (shows loss and val_loss)

history = model.fit(train_X, train_y, epochs=50, batch_size=72, validation_data=(test_X, test_y), verbose=2, shuffle=False)

#  print history
pyplot.plot(history.history['loss'])
pyplot.plot(history.history['val_loss'])
pyplot.title('Loss function')
pyplot.legend(['train', 'test'])
pyplot.xlabel('iterations')
pyplot.show()
# Out:
# Epoch 1/50
# 122/122 - 2s - loss: 0.0609 - val_loss: 0.0623 - 2s/epoch - 18ms/step
# Epoch 2/50
# 122/122 - 1s - loss: 0.0276 - val_loss: 0.0446 - 631ms/epoch - 5ms/step
# Epoch 3/50
# 122/122 - 1s - loss: 0.0214 - val_loss: 0.0264 - 635ms/epoch - 5ms/step
# Epoch 4/50
# 122/122 - 1s - loss: 0.0213 - val_loss: 0.0242 - 641ms/epoch - 5ms/step
# Epoch 5/50
# 122/122 - 1s - loss: 0.0204 - val_loss: 0.0224 - 622ms/epoch - 5ms/step
# Epoch 6/50
# 122/122 - 1s - loss: 0.0204 - val_loss: 0.0205 - 624ms/epoch - 5ms/step
# Epoch 7/50
# 122/122 - 1s - loss: 0.0199 - val_loss: 0.0203 - 625ms/epoch - 5ms/step
# Epoch 8/50
# 122/122 - 1s - loss: 0.0194 - val_loss: 0.0196 - 687ms/epoch - 6ms/step
# Epoch 9/50
# 122/122 - 1s - loss: 0.0188 - val_loss: 0.0193 - 626ms/epoch - 5ms/step
# Epoch 10/50
# 122/122 - 1s - loss: 0.0184 - val_loss: 0.0186 - 679ms/epoch - 6ms/step
# Epoch 11/50
# 122/122 - 1s - loss: 0.0178 - val_loss: 0.0185 - 620ms/epoch - 5ms/step
# Epoch 12/50
# 122/122 - 1s - loss: 0.0175 - val_loss: 0.0183 - 623ms/epoch - 5ms/step
# Epoch 13/50
# 122/122 - 1s - loss: 0.0170 - val_loss: 0.0178 - 675ms/epoch - 6ms/step
# Epoch 14/50
# 122/122 - 1s - loss: 0.0167 - val_loss: 0.0178 - 663ms/epoch - 5ms/step
# Epoch 15/50
# 122/122 - 1s - loss: 0.0162 - val_loss: 0.0171 - 620ms/epoch - 5ms/step
# Epoch 16/50
# 122/122 - 1s - loss: 0.0160 - val_loss: 0.0175 - 629ms/epoch - 5ms/step
# Epoch 17/50
# 122/122 - 1s - loss: 0.0155 - val_loss: 0.0177 - 783ms/epoch - 6ms/step
# Epoch 18/50
# 122/122 - 1s - loss: 0.0156 - val_loss: 0.0174 - 685ms/epoch - 6ms/step
# Epoch 19/50
# 122/122 - 1s - loss: 0.0155 - val_loss: 0.0175 - 689ms/epoch - 6ms/step
# Epoch 20/50
# 122/122 - 1s - loss: 0.0154 - val_loss: 0.0172 - 743ms/epoch - 6ms/step
# Epoch 21/50
# 122/122 - 1s - loss: 0.0149 - val_loss: 0.0178 - 655ms/epoch - 5ms/step
# Epoch 22/50
# 122/122 - 1s - loss: 0.0150 - val_loss: 0.0176 - 723ms/epoch - 6ms/step
# Epoch 23/50
# 122/122 - 1s - loss: 0.0149 - val_loss: 0.0171 - 718ms/epoch - 6ms/step
# Epoch 24/50
# 122/122 - 1s - loss: 0.0146 - val_loss: 0.0180 - 678ms/epoch - 6ms/step
# Epoch 25/50
# 122/122 - 1s - loss: 0.0146 - val_loss: 0.0173 - 625ms/epoch - 5ms/step
# Epoch 26/50
# 122/122 - 1s - loss: 0.0145 - val_loss: 0.0174 - 622ms/epoch - 5ms/step
# Epoch 27/50
# 122/122 - 1s - loss: 0.0145 - val_loss: 0.0173 - 630ms/epoch - 5ms/step
# Epoch 28/50
# 122/122 - 1s - loss: 0.0146 - val_loss: 0.0168 - 623ms/epoch - 5ms/step
# Epoch 29/50
# 122/122 - 1s - loss: 0.0145 - val_loss: 0.0158 - 621ms/epoch - 5ms/step
# Epoch 30/50
# 122/122 - 1s - loss: 0.0145 - val_loss: 0.0162 - 623ms/epoch - 5ms/step
# Epoch 31/50
# 122/122 - 1s - loss: 0.0144 - val_loss: 0.0156 - 621ms/epoch - 5ms/step
# Epoch 32/50
# 122/122 - 1s - loss: 0.0145 - val_loss: 0.0158 - 620ms/epoch - 5ms/step
# Epoch 33/50
# 122/122 - 1s - loss: 0.0145 - val_loss: 0.0155 - 621ms/epoch - 5ms/step
# Epoch 34/50
# 122/122 - 1s - loss: 0.0145 - val_loss: 0.0155 - 625ms/epoch - 5ms/step
# Epoch 35/50
# 122/122 - 1s - loss: 0.0145 - val_loss: 0.0152 - 620ms/epoch - 5ms/step
# Epoch 36/50
# 122/122 - 1s - loss: 0.0145 - val_loss: 0.0148 - 618ms/epoch - 5ms/step
# Epoch 37/50
# 122/122 - 1s - loss: 0.0144 - val_loss: 0.0151 - 696ms/epoch - 6ms/step
# Epoch 38/50
# 122/122 - 1s - loss: 0.0144 - val_loss: 0.0149 - 628ms/epoch - 5ms/step
# Epoch 39/50
# 122/122 - 1s - loss: 0.0144 - val_loss: 0.0150 - 624ms/epoch - 5ms/step
# Epoch 40/50
# 122/122 - 1s - loss: 0.0144 - val_loss: 0.0147 - 617ms/epoch - 5ms/step
# Epoch 41/50
# 122/122 - 1s - loss: 0.0142 - val_loss: 0.0143 - 617ms/epoch - 5ms/step
# Epoch 42/50
# 122/122 - 1s - loss: 0.0143 - val_loss: 0.0145 - 620ms/epoch - 5ms/step
# Epoch 43/50
# 122/122 - 1s - loss: 0.0143 - val_loss: 0.0143 - 619ms/epoch - 5ms/step
# Epoch 44/50
# 122/122 - 1s - loss: 0.0144 - val_loss: 0.0145 - 619ms/epoch - 5ms/step
# Epoch 45/50
# 122/122 - 1s - loss: 0.0144 - val_loss: 0.0143 - 619ms/epoch - 5ms/step
# Epoch 46/50
# 122/122 - 1s - loss: 0.0143 - val_loss: 0.0144 - 623ms/epoch - 5ms/step
# Epoch 47/50
# 122/122 - 1s - loss: 0.0143 - val_loss: 0.0143 - 624ms/epoch - 5ms/step
# Epoch 48/50
# 122/122 - 1s - loss: 0.0142 - val_loss: 0.0140 - 619ms/epoch - 5ms/step
# Epoch 49/50
# 122/122 - 1s - loss: 0.0143 - val_loss: 0.0142 - 623ms/epoch - 5ms/step
# Epoch 50/50
# 122/122 - 1s - loss: 0.0143 - val_loss: 0.0141 - 623ms/epoch - 5ms/step

# %% [markdown]
# ## Evaluate Model
# After the model is fit, apply it to predict test data.
# Compare the predictions (yhat) and the real data (test_y) as shown in Fig. 2.
#
# <img src="images/f2.png" style="width:350px;height:250px;">
# <caption><center> **Fig. 1** : ** Test data prediction (the first 2000 samples)** </center></caption>

# %%
#Apply the model to predict the test data
yhat = model.predict(test_X)

# Compute the Mean Squared Error (MSE) on test data with function mean_squared_error 
#(ANSWER: Test mse = 0.001)
mse = mean_squared_error(y_true=test_y, y_pred=yhat)
print(f"{mse = }")


#Plot test_y and yhat on the same plot. 
#use pyplot from matplotlib
#Since test data has huge amount of samples (35037), the plot visibility is bad. 
#To improve it choose to plot only the fist 2000 samples.
n_plot_samples = 2000
x = range(n_plot_samples)

plt.plot(x, test_y[:n_plot_samples], label="real data")
plt.plot(x, yhat[:n_plot_samples], label="predictions", color="red")
plt.legend()
plt.title("Air Pollution Forecasting")
# Out:
# 1095/1095 [==============================] - 1s 819us/step
# mse = 0.0007166263
# Text(0.5, 1.0, 'Air Pollution Forecasting')

# %%
#Apply the model to predict the train data
yhat = model.predict(train_X)

#Plot train_y and yhat on the same plot. 
#use pyplot from matplotlib
#Since test data has huge amount of samples (35037), the plot visibility is bad. 
#To improve it choose to plot only the fist 2000 samples.
n_plot_samples = 2000
x = range(n_plot_samples)

plt.plot(x, train_y[:n_plot_samples], label="real data")
plt.plot(x, yhat[:n_plot_samples], label="predictions", color="red")
plt.legend()
plt.title("Air Pollution Forecasting")
# Out:
# 274/274 [==============================] - 0s 846us/step
# Text(0.5, 1.0, 'Air Pollution Forecasting')
